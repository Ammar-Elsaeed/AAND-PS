# %% [markdown]
# # 1. Trial-Averaged Firing Rates (7 points)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
## Load spike times
spike_times = np.loadtxt('SpikeTimes.dat')
spike_times /= 1000 # convert from ms to s.

assert spike_times.shape[0] == 100  # maximum spike-time index.
assert spike_times.shape[1] == 100  # number of trials.

# %%
T = 5.5 # [s]
time_resolution = 100 # [s]

# %% [markdown]
# 1.a) Make a raster plot using the pyplot function eventplot. You may need to set the axes limits manually for correct visualization.

# %%
# plt.figure(figsize=(15, 5))
# plt.xlim()
# set different colors for each set of positions
colors = ['C{}'.format(i) for i in range(100)]
plt.eventplot(spike_times, colors = colors, linelengths=1, lineoffsets=1)
plt.show()


# colors

# # set different line properties for each set of positions
# # note that some overlap
# lineoffsets1 = np.array([-15, -3, 1, 1.5, 6, 10])
# linelengths1 = [5, 2, 1, 1, 3, 1.5]

# fig, axs = plt.subplots(2, 2)

# # create a horizontal plot
# axs[0, 0].eventplot(data1, colors=colors1, lineoffsets=lineoffsets1,
#                     linelengths=linelengths1)
